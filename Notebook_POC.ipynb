# %% [markdown]
# # Análisis exploratorio de las imágenes

# %% [markdown]
# Mes de marzo

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib

imagenes = [
    'AQUA_MODIS.20100301_20100331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20150301_20150331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20190301_20190331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20240301_20240331.L3m.MO.POC.x_poc.nc.png'
]

vmin, vmax = 80, 200
cmap_name = 'Spectral'
cmap = matplotlib.colormaps[cmap_name]
norm = Normalize(vmin=vmin, vmax=vmax)

fig, axs = plt.subplots(2, 2, figsize=(16, 10))
axs = axs.flatten()

for i, nombre in enumerate(imagenes):
    ruta = os.path.join("poc_dataset", nombre)
    img = cv2.imread(ruta, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"No se pudo cargar {nombre}")
        continue

    img = img.astype(np.float32)
    mask = img > 0
    img_norm = (img - vmin) / (vmax - vmin)
    img_norm = np.clip(img_norm, 0, 1)

    img_color = np.zeros((*img.shape, 3))
    img_color[mask] = cmap(img_norm[mask])[:, :3]

    #im = axs[i].imshow(img_color)
    axs[i].imshow(img_color)
    axs[i].set_title(f"Marzo {nombre[11:15]} (POC)")
    axs[i].set_ylabel("POC (mg m^-3)", fontsize=11)
    axs[i].tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)

    cbar = fig.colorbar(ScalarMappable(norm=norm, cmap=cmap), ax=axs[i], orientation='vertical', fraction=0.046, pad=0.02)
    cbar.set_label("POC", fontsize=10)
fig.suptitle('Eventos de El Niño', fontsize=20, y = 1.05)
plt.tight_layout()
plt.show()

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib

imagenes = [
    'AQUA_MODIS.20060301_20060331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20080301_20080331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20090301_20090331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20120301_20120331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20180301_20180331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20220301_20220331.L3m.MO.POC.x_poc.nc.png'
]

vmin, vmax = 60, 210
cmap_name = 'Spectral'
cmap = matplotlib.colormaps[cmap_name]
norm = Normalize(vmin=vmin, vmax=vmax)

fig, axs = plt.subplots(3, 2, figsize=(16, 10))
axs = axs.flatten()

for i, nombre in enumerate(imagenes):
    ruta = os.path.join("poc_dataset", nombre)
    img = cv2.imread(ruta, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"No se pudo cargar {nombre}")
        continue

    img = img.astype(np.float32)
    mask = img > 0
    img_norm = (img - vmin) / (vmax - vmin)
    img_norm = np.clip(img_norm, 0, 1)

    img_color = np.zeros((*img.shape, 3))
    img_color[mask] = cmap(img_norm[mask])[:, :3]

    #im = axs[i].imshow(img_color)
    axs[i].imshow(img_color)
    axs[i].set_title(f"Marzo {nombre[11:15]} (POC)")
    axs[i].set_ylabel("POC (mg m^-3)", fontsize=11)
    axs[i].tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)

    cbar = fig.colorbar(ScalarMappable(norm=norm, cmap=cmap), ax=axs[i], orientation='vertical', fraction=0.046, pad=0.02)
    cbar.set_label("POC", fontsize=10)
fig.suptitle('Eventos de La Niña', fontsize=20, y = 1.05)
plt.tight_layout()
plt.show()

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib

imagenes = [
    'AQUA_MODIS.20030301_20030331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20040301_20040331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20050301_20050331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20070301_20070331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20130301_20130331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20140301_20140331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20170301_20170331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20200301_20200331.L3m.MO.POC.x_poc.nc.png',
    'AQUA_MODIS.20230301_20230331.L3m.MO.POC.x_poc.nc.png'
]

vmin, vmax = 60, 210
cmap_name = 'Spectral'
cmap = matplotlib.colormaps[cmap_name]
norm = Normalize(vmin=vmin, vmax=vmax)

fig, axs = plt.subplots(3, 3, figsize=(16, 10))
axs = axs.flatten()

for i, nombre in enumerate(imagenes):
    ruta = os.path.join("poc_dataset", nombre)
    img = cv2.imread(ruta, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"No se pudo cargar {nombre}")
        continue

    img = img.astype(np.float32)
    mask = img > 0
    img_norm = (img - vmin) / (vmax - vmin)
    img_norm = np.clip(img_norm, 0, 1)

    img_color = np.zeros((*img.shape, 3))
    img_color[mask] = cmap(img_norm[mask])[:, :3]

    #im = axs[i].imshow(img_color)
    axs[i].imshow(img_color)
    axs[i].set_title(f"Marzo {nombre[11:15]} (POC)")
    axs[i].set_ylabel("POC (mg m^-3)", fontsize=11)
    axs[i].tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)

    cbar = fig.colorbar(ScalarMappable(norm=norm, cmap=cmap), ax=axs[i], orientation='vertical', fraction=0.046, pad=0.02)
    cbar.set_label("POC", fontsize=10)
fig.suptitle('Eventos de la Fase Neutra', fontsize=20, y = 1.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# Mes de noviembre

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib


imagenes = [
'AQUA_MODIS.20021101_20021130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20041101_20041130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20061101_20061130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20091101_20091130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20141101_20141130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20151101_20151130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20181101_20181130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20231101_20231130.L3m.MO.POC.x_poc.nc.png'
]

vmin, vmax = 60, 210
cmap_name = 'Spectral'
cmap = matplotlib.colormaps[cmap_name]
norm = Normalize(vmin=vmin, vmax=vmax)

fig, axs = plt.subplots(3, 3, figsize=(16, 10))
axs = axs.flatten()

for i, nombre in enumerate(imagenes):
    ruta = os.path.join("poc_dataset", nombre)
    img = cv2.imread(ruta, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"No se pudo cargar {nombre}")
        continue

    img = img.astype(np.float32)
    mask = img > 0
    img_norm = (img - vmin) / (vmax - vmin)
    img_norm = np.clip(img_norm, 0, 1)

    img_color = np.zeros((*img.shape, 3))
    img_color[mask] = cmap(img_norm[mask])[:, :3]

    #im = axs[i].imshow(img_color)
    axs[i].imshow(img_color)
    axs[i].set_title(f"Noviembre {nombre[11:15]} (POC)")
    axs[i].set_ylabel("POC (mg m^-3)", fontsize=11)
    axs[i].tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)

    cbar = fig.colorbar(ScalarMappable(norm=norm, cmap=cmap), ax=axs[i], orientation='vertical', fraction=0.046, pad=0.02)
    cbar.set_label("POC", fontsize=10)
fig.suptitle('Eventos de El Niño', fontsize=20, y = 1.05)
axs[8].remove()
plt.tight_layout()
plt.show()

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib


imagenes = [
'AQUA_MODIS.20051101_20051130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20071101_20071130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20081101_20081130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20101101_20101130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20111101_20111130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20161101_20161130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20171101_20171130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20201101_20201130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20211101_20211130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20221101_20221130.L3m.MO.POC.x_poc.nc.png'
]

vmin, vmax = 60, 210
cmap_name = 'Spectral'
cmap = matplotlib.colormaps[cmap_name]
norm = Normalize(vmin=vmin, vmax=vmax)

fig, axs = plt.subplots(5, 2, figsize=(16, 10))
axs = axs.flatten()

for i, nombre in enumerate(imagenes):
    ruta = os.path.join("poc_dataset", nombre)
    img = cv2.imread(ruta, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"No se pudo cargar {nombre}")
        continue

    img = img.astype(np.float32)
    mask = img > 0
    img_norm = (img - vmin) / (vmax - vmin)
    img_norm = np.clip(img_norm, 0, 1)

    img_color = np.zeros((*img.shape, 3))
    img_color[mask] = cmap(img_norm[mask])[:, :3]

    #im = axs[i].imshow(img_color)
    axs[i].imshow(img_color)
    axs[i].set_title(f"Noviembre {nombre[11:15]} (POC)")
    axs[i].set_ylabel("POC (mg m^-3)", fontsize=11)
    axs[i].tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)

    cbar = fig.colorbar(ScalarMappable(norm=norm, cmap=cmap), ax=axs[i], orientation='vertical', fraction=0.046, pad=0.02)
    cbar.set_label("POC", fontsize=10)
fig.suptitle('Eventos de La Niña', fontsize=18, y = 1.03, x = 0.6)
plt.tight_layout()
plt.show()

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib


imagenes = [
'AQUA_MODIS.20031101_20031130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20121101_20121130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20131101_20131130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20191101_20191130.L3m.MO.POC.x_poc.nc.png',
'AQUA_MODIS.20241101_20241130.L3m.MO.POC.x_poc.nc.png'
]

vmin, vmax = 60, 210
cmap_name = 'Spectral'
cmap = matplotlib.colormaps[cmap_name]
norm = Normalize(vmin=vmin, vmax=vmax)

fig, axs = plt.subplots(3, 2, figsize=(16, 10))
axs = axs.flatten()

for i, nombre in enumerate(imagenes):
    ruta = os.path.join("poc_dataset", nombre)
    img = cv2.imread(ruta, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"No se pudo cargar {nombre}")
        continue

    img = img.astype(np.float32)
    mask = img > 0
    img_norm = (img - vmin) / (vmax - vmin)
    img_norm = np.clip(img_norm, 0, 1)

    img_color = np.zeros((*img.shape, 3))
    img_color[mask] = cmap(img_norm[mask])[:, :3]

    #im = axs[i].imshow(img_color)
    axs[i].imshow(img_color)
    axs[i].set_title(f"Noviembre {nombre[11:15]} (POC)")
    axs[i].set_ylabel("POC (mg m^-3)", fontsize=11)
    axs[i].tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)

    cbar = fig.colorbar(ScalarMappable(norm=norm, cmap=cmap), ax=axs[i], orientation='vertical', fraction=0.046, pad=0.02)
    cbar.set_label("POC", fontsize=10)
fig.suptitle('Eventos de la Fase Neutra', fontsize=22, y = 1.05)
axs[5].remove()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Modelo Autoencoder

# %% [markdown]
# Preprocesamiento de las imágenes

# %%
from datetime import datetime

from os import listdir
lista_img = listdir('/content/poc_dataset')

def ordenar_lista_cronologicamente(lista_img):
    return sorted(lista_img, key=lambda x: datetime.strptime(x.split('.')[1][:6], "%Y%m"))


import cv2
import numpy as np
import pandas as pd
from datetime import datetime


def generar_dataset_completo(lista_poc, size=(16, 42)):
    lista_poc = ordenar_lista_cronologicamente(lista_poc)
    fechas_poc = [f.split('.')[1][:6] for f in lista_poc]

    dataset = []
    registros = []

    for poc_img in lista_poc:
        img_poc = cv2.imread('poc_dataset/' + poc_img)


        img_poc = cv2.cvtColor(img_poc, cv2.COLOR_BGR2GRAY)
        img_poc = img_poc.astype(np.float32) / 255.0
        img_poc = img_poc[..., np.newaxis]

        dataset.append(img_poc)
        registros.append({
            'fecha': poc_img.split('.')[1][:6],
            'nombre_poc': poc_img
        })

    dataset = np.array(dataset)
    df_nom_fechas = pd.DataFrame(registros)

    return dataset, df_nom_fechas

# %% [markdown]
# Bloque Encoder

# %%
from tensorflow.keras import layers, models
from tensorflow.keras import backend as K

def encoder(input_shape = (16,42,1), latent_dim = 10):
  inputs = layers.Input(shape=input_shape)
  #Primera capa
  x = layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')(inputs)  #(8, 21, 32)
  x = layers.BatchNormalization()(x)

  encoder_output_shape = K.int_shape(x)[1:]
  #Aplanar para preparar la salida del encoder
  x = layers.Flatten()(x)
  encoder_output = layers.Dense(latent_dim)(x)

  modelo_encoder = models.Model(inputs=inputs, outputs=encoder_output, name="Encoder")
  return encoder_output_shape, modelo_encoder

# %% [markdown]
# Bloque Decoder

# %%
def decoder(encoder_output_shape, latent_dim = 10):
  inputs = layers.Input(shape= (latent_dim,))

  #Primera capa lineal
  x = layers.Dense(np.prod(encoder_output_shape))(inputs)
  x = layers.Reshape(encoder_output_shape)(x)

  #Segunda capa
  x = layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu')(x)  #(16, 42, 32)
  x = layers.BatchNormalization()(x)

  #Hacemos Conv2DTranspose = upsampling + Conv2D, última capa activación sigmoid -> salida entre 0 y 1.
  output_decoder = layers.Conv2DTranspose(1, (3,3), padding='same', activation = 'sigmoid') (x)

  modelo_decoder = models.Model(inputs = inputs, outputs = output_decoder, name = "Decoder")
  return modelo_decoder

# %% [markdown]
# Bloque Autoencoder: Encoder + Decoder

# %%
def autoencoder (input_shape = (16, 42, 1), latent_dim = 10):
  encoder_output_shape, modelo_encoder = encoder(input_shape, latent_dim)
  modelo_decoder = decoder(encoder_output_shape, latent_dim)
  #para que la parte del encoder
  #quede nombrada como Encoder y así podamos extraer los pesos desde el AE
  inputs = layers.Input(shape=input_shape)
  encoder_output = modelo_encoder(inputs)  #uso del encoder como capa-modelo
  decoder_output = modelo_decoder(encoder_output)

  modelo_autoencoder = models.Model(inputs = inputs, outputs = decoder_output, name = "Autoencoder")

  return modelo_encoder, modelo_decoder, modelo_autoencoder

# %% [markdown]
# Compilación del modelo Autoencoder

# %%
from tensorflow.keras.optimizers import Adam
def compilar(modelo, learning_rate = 0.0005, loss = 'mse'):
  optimizer = Adam(learning_rate=learning_rate)
  modelo.compile(optimizer=optimizer, loss=loss)
  return modelo

# %% [markdown]
# Definir el entrenamiento del modelo Autoencoder

# %%
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint

def entrenar_modelo(modelo, x_train, batch_size =8, epochs = 100, validation_split = 0.1, usar_callbacks = True,
                    checkpoint_ruta = 'poc_archivos/autoencoder.weights.h5', log_ruta = 'poc_archivos/log_entrenamiento.csv'):
  callbacks = []
  if usar_callbacks:
    callbacks = [CSVLogger(log_ruta),
                 ModelCheckpoint(checkpoint_ruta,
                                 monitor = "val_loss",
                                 save_weights_only=True,
                                 save_best_only=True,
                                 verbose=1),
                                EarlyStopping(monitor = "val_loss", patience = 25)]
  #No ponemos steps_per_epoch porque steps_per_epoch = len(x_train) // batch_size esto solo hace falta cuando el
  #dataset es muy grande o los datos provienen de un dataflow.
  historico = modelo.fit(x_train,
                       x_train, #al ser autoencoder el output debe ser el mismo tras todas las transformaciones
                       batch_size=batch_size,
                       epochs=epochs,
                       validation_split=validation_split,
                       callbacks=callbacks)
  return historico

# %% [markdown]
# Entrenar el modelo Autoencoder

# %%
#Ejecutar AE
dataset_compacto, df_info = generar_dataset_completo(lista_img)

modelo_encoder, modelo_decoder, modelo_autoencoder = autoencoder()
modelo_autoencoder = compilar(modelo_autoencoder)
historico = entrenar_modelo (x_train = dataset_compacto,modelo = modelo_autoencoder)

#Cargar el modelo autoencoder con los mejores pesos entrenados
modelo_autoencoder.load_weights('poc_archivos/autoencoder.weights.h5')
#Extraer los pesos de la parte del Encoder
modelo_encoder.set_weights(modelo_autoencoder.get_layer("Encoder").get_weights())
modelo_encoder.save("poc_archivos/encoder_entrenado.h5")

#Cargar el modelo encoder para obtener el espacio latente de las imgs
from tensorflow.keras.models import load_model

encoder = load_model('poc_archivos/encoder_entrenado.h5')
espacio_latente = encoder.predict(dataset_compacto)
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0677
# Epoch 1: val_loss improved from inf to 0.07394, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.0671 - val_loss: 0.0739
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0213
# Epoch 2: val_loss improved from 0.07394 to 0.07280, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0214 - val_loss: 0.0728
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0203
# Epoch 3: val_loss improved from 0.07280 to 0.07024, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0203 - val_loss: 0.0702
# Epoch 4/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0206
# Epoch 4: val_loss improved from 0.07024 to 0.06847, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0205 - val_loss: 0.0685
# Epoch 5/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0194
# Epoch 5: val_loss improved from 0.06847 to 0.06560, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0193 - val_loss: 0.0656
# Epoch 6/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0167
# Epoch 6: val_loss improved from 0.06560 to 0.06378, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0167 - val_loss: 0.0638
# Epoch 7/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0160
# Epoch 7: val_loss improved from 0.06378 to 0.06048, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0160 - val_loss: 0.0605
# Epoch 8/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0160
# Epoch 8: val_loss improved from 0.06048 to 0.05748, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0159 - val_loss: 0.0575
# Epoch 9/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0150
# Epoch 9: val_loss improved from 0.05748 to 0.05312, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0149 - val_loss: 0.0531
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0149
# Epoch 10: val_loss improved from 0.05312 to 0.04811, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0149 - val_loss: 0.0481
# Epoch 11/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0139
# Epoch 11: val_loss improved from 0.04811 to 0.04436, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0139 - val_loss: 0.0444
# Epoch 12/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0139
# Epoch 12: val_loss improved from 0.04436 to 0.03861, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0139 - val_loss: 0.0386
# Epoch 13/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0132
# Epoch 13: val_loss improved from 0.03861 to 0.03090, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0132 - val_loss: 0.0309
# Epoch 14/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0128
# Epoch 14: val_loss improved from 0.03090 to 0.02624, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0128 - val_loss: 0.0262
# Epoch 15/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0121
# Epoch 15: val_loss improved from 0.02624 to 0.02040, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0121 - val_loss: 0.0204
# Epoch 16/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0124
# Epoch 16: val_loss improved from 0.02040 to 0.01080, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0125 - val_loss: 0.0108
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0140
# Epoch 17: val_loss improved from 0.01080 to 0.00961, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0140 - val_loss: 0.0096
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0126
# Epoch 18: val_loss improved from 0.00961 to 0.00875, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0126 - val_loss: 0.0088
# Epoch 19/100
# 28/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0110
# Epoch 19: val_loss did not improve from 0.00875
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0111 - val_loss: 0.0088
# Epoch 20/100
# 28/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0113
# Epoch 20: val_loss improved from 0.00875 to 0.00766, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0113 - val_loss: 0.0077
# Epoch 21/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0117
# Epoch 21: val_loss improved from 0.00766 to 0.00751, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0117 - val_loss: 0.0075
# Epoch 22/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0109
# Epoch 22: val_loss improved from 0.00751 to 0.00730, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0109 - val_loss: 0.0073
# Epoch 23/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0106
# Epoch 23: val_loss improved from 0.00730 to 0.00679, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0106 - val_loss: 0.0068
# Epoch 24/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0100
# Epoch 24: val_loss improved from 0.00679 to 0.00675, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0100 - val_loss: 0.0067
# Epoch 25/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0109
# Epoch 25: val_loss improved from 0.00675 to 0.00674, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0109 - val_loss: 0.0067
# Epoch 26/100
# 27/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0103
# Epoch 26: val_loss improved from 0.00674 to 0.00657, saving model to poc_archivos/autoencoder.weights.h5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0104 - val_loss: 0.0066
# Epoch 27/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0103
# Epoch 27: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0104 - val_loss: 0.0067
# Epoch 28/100
# 28/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0102
# Epoch 28: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0102 - val_loss: 0.0067
# Epoch 29/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0104
# Epoch 29: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0104 - val_loss: 0.0077
# Epoch 30/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0098
# Epoch 30: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0099 - val_loss: 0.0067
# Epoch 31/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0107
# Epoch 31: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0107 - val_loss: 0.0067
# Epoch 32/100
# 28/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0099
# Epoch 32: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0099 - val_loss: 0.0066
# Epoch 33/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0094
# Epoch 33: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0095 - val_loss: 0.0069
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0101
# Epoch 34: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0101 - val_loss: 0.0070
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0101
# Epoch 35: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0101 - val_loss: 0.0077
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0096
# Epoch 36: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0096 - val_loss: 0.0070
# Epoch 37/100
# 28/31 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0095
# Epoch 37: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0095 - val_loss: 0.0072
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0091
# Epoch 38: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0091 - val_loss: 0.0069
# Epoch 39/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0090
# Epoch 39: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0091 - val_loss: 0.0068
# Epoch 40/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0093
# Epoch 40: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0093 - val_loss: 0.0069
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0092
# Epoch 41: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0092 - val_loss: 0.0068
# Epoch 42/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0089
# Epoch 42: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0090 - val_loss: 0.0070
# Epoch 43/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0085
# Epoch 43: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0085 - val_loss: 0.0070
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0083
# Epoch 44: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0083 - val_loss: 0.0073
# Epoch 45/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0090
# Epoch 45: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0090 - val_loss: 0.0071
# Epoch 46/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0088
# Epoch 46: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0089 - val_loss: 0.0072
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0084
# Epoch 47: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0084 - val_loss: 0.0071
# Epoch 48/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0087
# Epoch 48: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0087 - val_loss: 0.0072
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0080
# Epoch 49: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0080 - val_loss: 0.0073
# Epoch 50/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0080
# Epoch 50: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0080 - val_loss: 0.0073
# Epoch 51/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0082
# Epoch 51: val_loss did not improve from 0.00657
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0082 - val_loss: 0.0077
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# Visualizar una muestra de las imágenes originales vs reconstruidas

# %%
#Visualizar las reconstrucciones del AE
import matplotlib.pyplot as plt
reconstrucciones = modelo_autoencoder.predict(dataset_compacto)
for i in range(5):
    plt.subplot(2, 5, i+1)
    plt.imshow(dataset_compacto[i], cmap='gray', vmin=0, vmax=1)
    plt.axis('off')

    plt.subplot(2, 5, i+6)
    plt.imshow(reconstrucciones[i], cmap='gray', vmin=0, vmax=1)
    plt.axis('off')

plt.suptitle("Variable POC: Original (arriba) vs Reconstruida (abajo)", y = 0.8)
plt.subplots_adjust(hspace=0.05)
plt.tight_layout()
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ###### Contrastes de hipótesis

# %% [markdown]
# Crear función con la que aplicar contrates de hipótesis de normalidad, homocedasticidad y comparación entre grupos

# %%
# !pip install pingouin
# Out:
# Collecting pingouin
#   Downloading pingouin-0.5.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pingouin) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pingouin) (2.0.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.11/dist-packages (from pingouin) (2.2.2)
# Collecting pandas-flavor (from pingouin)
#   Downloading pandas_flavor-0.7.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.11/dist-packages (from pingouin) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pingouin) (1.15.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from pingouin) (0.13.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from pingouin) (0.14.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from pingouin) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5->pingouin) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5->pingouin) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5->pingouin) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2->pingouin) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2->pingouin) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pingouin) (3.2.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from pandas-flavor->pingouin) (2025.3.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->pingouin) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->pingouin) (1.17.0)
# Downloading pingouin-0.5.5-py3-none-any.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 kB 7.2 MB/s eta 0:00:00
# Downloading pandas_flavor-0.7.0-py3-none-any.whl (8.4 kB)
# Installing collected packages: pandas-flavor, pingouin
# Successfully installed pandas-flavor-0.7.0 pingouin-0.5.5

# %%
from scipy.stats import shapiro, levene, f_oneway, mannwhitneyu
import pingouin as pg

def analizar_contraste(df, variable, fase_col='fases'):
    print(f"\nVariable: {variable}")

    normales = []
    for fase in df[fase_col].unique():
        grupo = df[df[fase_col] == fase][variable]
        stat, p = shapiro(grupo)
        normales.append(p > 0.05)
        print(f" - Normalidad en {fase}: p-valor = {p:.4f}")

    normalidad = all(normales)

    if normalidad:
        grupo1 = df[df[fase_col] == df[fase_col].unique()[0]][variable]
        grupo2 = df[df[fase_col] == df[fase_col].unique()[1]][variable]
        stat, p_levene = levene(grupo1, grupo2)
        print(f" - Homocedasticidad (Levene): p-valor = {p_levene:.4f}")

        if p_levene > 0.05:
            stat, p_anova = f_oneway(grupo1, grupo2)
            print(f"ANOVA clásico: p-valor = {p_anova:.4f}")
        else:
            resultado = pg.welch_anova(dv=variable, between=fase_col, data=df)
            print(f"Welch: p-valor = {resultado['p-unc'].values[0]:.4f}")

    else:
        grupo1 = df[df[fase_col] == df[fase_col].unique()[0]][variable]
        grupo2 = df[df[fase_col] == df[fase_col].unique()[1]][variable]
        stat, p_mw = mannwhitneyu(grupo1, grupo2, alternative='two-sided')
        print(f"Mann-Whitney U: p-valor = {p_mw:.4f}")

# %% [markdown]
# Contraste de hipótesis en Enero: Fase El Niño vs Fase La Niña

# %%
df_ene_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_ene_contraste["fecha"] = df_info["fecha"]
df_ene_contraste = df_ene_contraste[df_ene_contraste["fecha"].str[4:] == "01"].reset_index(drop=True)
df_ene_contraste["fases"] = ["niño", "neutra", "niño", "niña", "niño", "niña", "niña", "niño",
                                      "niña", "niña", "neutra", "neutra", "niño", "niño", "neutra",
                                      "niña", "niño", "neutra", "niña", "niña", "niña", "niño", "neutra"]
df_ene_contraste = df_ene_contraste[df_ene_contraste["fases"] != "neutra"]
df_ene_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_ene_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niño: p-valor = 0.7636
#  - Normalidad en niña: p-valor = 0.2741
#  - Homocedasticidad (Levene): p-valor = 0.6967
# ANOVA clásico: p-valor = 0.0500
#
# Variable: caract2
#  - Normalidad en niño: p-valor = 0.5706
#  - Normalidad en niña: p-valor = 0.8622
#  - Homocedasticidad (Levene): p-valor = 0.6098
# ANOVA clásico: p-valor = 0.0245
#
# Variable: caract3
#  - Normalidad en niño: p-valor = 0.9708
#  - Normalidad en niña: p-valor = 0.9201
#  - Homocedasticidad (Levene): p-valor = 0.6965
# ANOVA clásico: p-valor = 0.6671
#
# Variable: caract4
#  - Normalidad en niño: p-valor = 0.1576
#  - Normalidad en niña: p-valor = 0.7784
#  - Homocedasticidad (Levene): p-valor = 0.0734
# ANOVA clásico: p-valor = 0.1946
#
# Variable: caract5
#  - Normalidad en niño: p-valor = 0.5580
#  - Normalidad en niña: p-valor = 0.2970
#  - Homocedasticidad (Levene): p-valor = 0.8054
# ANOVA clásico: p-valor = 0.7074
#
# Variable: caract6
#  - Normalidad en niño: p-valor = 0.7885
#  - Normalidad en niña: p-valor = 0.1231
#  - Homocedasticidad (Levene): p-valor = 0.5256
# ANOVA clásico: p-valor = 0.7656
#
# Variable: caract7
#  - Normalidad en niño: p-valor = 0.9179
#  - Normalidad en niña: p-valor = 0.2854
#  - Homocedasticidad (Levene): p-valor = 0.8872
# ANOVA clásico: p-valor = 0.1503
#
# Variable: caract8
#  - Normalidad en niño: p-valor = 0.2469
#  - Normalidad en niña: p-valor = 0.3781
#  - Homocedasticidad (Levene): p-valor = 0.4064
# ANOVA clásico: p-valor = 0.0186
#
# Variable: caract9
#  - Normalidad en niño: p-valor = 0.3926
#  - Normalidad en niña: p-valor = 0.6439
#  - Homocedasticidad (Levene): p-valor = 0.1815
# ANOVA clásico: p-valor = 0.9202
#
# Variable: caract10
#  - Normalidad en niño: p-valor = 0.7671
#  - Normalidad en niña: p-valor = 0.2786
#  - Homocedasticidad (Levene): p-valor = 0.1848
# ANOVA clásico: p-valor = 0.7085

# %% [markdown]
# Contraste de hipótesis en Febrero: Fase El Niño vs Fase La Niña

# %%
df_feb_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_feb_contraste["fecha"] = df_info["fecha"]
df_feb_contraste = df_feb_contraste[df_feb_contraste["fecha"].str[4:] == "02"].reset_index(drop=True)
df_feb_contraste["fases"] = ["niño", "neutra", "niño", "niña", "neutra", "niña", "niña", "niño",
                                      "niña", "niña", "neutra", "neutra", "niño", "niño", "neutra",
                                      "niña", "niño", "neutra", "niña", "niña", "neutra", "niño", "neutra"]
df_feb_contraste = df_feb_contraste[df_feb_contraste["fases"] != "neutra"]
df_feb_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_feb_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niño: p-valor = 0.5956
#  - Normalidad en niña: p-valor = 0.8679
#  - Homocedasticidad (Levene): p-valor = 0.2472
# ANOVA clásico: p-valor = 0.0123
#
# Variable: caract2
#  - Normalidad en niño: p-valor = 0.0982
#  - Normalidad en niña: p-valor = 0.8156
#  - Homocedasticidad (Levene): p-valor = 0.5281
# ANOVA clásico: p-valor = 0.0387
#
# Variable: caract3
#  - Normalidad en niño: p-valor = 0.2961
#  - Normalidad en niña: p-valor = 0.0804
#  - Homocedasticidad (Levene): p-valor = 0.1007
# ANOVA clásico: p-valor = 0.4337
#
# Variable: caract4
#  - Normalidad en niño: p-valor = 0.2425
#  - Normalidad en niña: p-valor = 0.3583
#  - Homocedasticidad (Levene): p-valor = 0.2591
# ANOVA clásico: p-valor = 0.3948
#
# Variable: caract5
#  - Normalidad en niño: p-valor = 0.9075
#  - Normalidad en niña: p-valor = 0.6543
#  - Homocedasticidad (Levene): p-valor = 0.9888
# ANOVA clásico: p-valor = 0.2897
#
# Variable: caract6
#  - Normalidad en niño: p-valor = 0.2443
#  - Normalidad en niña: p-valor = 0.5687
#  - Homocedasticidad (Levene): p-valor = 0.7363
# ANOVA clásico: p-valor = 0.1743
#
# Variable: caract7
#  - Normalidad en niño: p-valor = 0.5371
#  - Normalidad en niña: p-valor = 0.0457
# Mann-Whitney U: p-valor = 0.0140
#
# Variable: caract8
#  - Normalidad en niño: p-valor = 0.3420
#  - Normalidad en niña: p-valor = 0.0974
#  - Homocedasticidad (Levene): p-valor = 0.9742
# ANOVA clásico: p-valor = 0.0427
#
# Variable: caract9
#  - Normalidad en niño: p-valor = 0.3270
#  - Normalidad en niña: p-valor = 0.8120
#  - Homocedasticidad (Levene): p-valor = 0.2802
# ANOVA clásico: p-valor = 0.0358
#
# Variable: caract10
#  - Normalidad en niño: p-valor = 0.9388
#  - Normalidad en niña: p-valor = 0.6977
#  - Homocedasticidad (Levene): p-valor = 0.7299
# ANOVA clásico: p-valor = 0.6101

# %% [markdown]
# Contraste de hipótesis en Marzo: Fase El Niño vs Fase La Niña

# %%
df_mar_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_mar_contraste["fecha"] = df_info["fecha"]
df_mar_contraste = df_mar_contraste[df_mar_contraste["fecha"].str[4:] == "03"].reset_index(drop=True)
df_mar_contraste["fases"] = ["neutra", "neutra", "neutra", "niña",
                                      "neutra", "niña", "niña", "niño", "niña", "niña",
                                      "neutra", "neutra", "niño", "niño", "neutra",
                                      "niña", "niño", "neutra", "niña", "niña",
                                      "neutra", "niño"]
df_mar_contraste = df_mar_contraste[df_mar_contraste["fases"] != "neutra"]
df_mar_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_mar_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niña: p-valor = 0.7112
#  - Normalidad en niño: p-valor = 0.6308
#  - Homocedasticidad (Levene): p-valor = 0.1003
# ANOVA clásico: p-valor = 0.9915
#
# Variable: caract2
#  - Normalidad en niña: p-valor = 0.9827
#  - Normalidad en niño: p-valor = 0.2454
#  - Homocedasticidad (Levene): p-valor = 0.4969
# ANOVA clásico: p-valor = 0.1417
#
# Variable: caract3
#  - Normalidad en niña: p-valor = 0.6253
#  - Normalidad en niño: p-valor = 0.0788
#  - Homocedasticidad (Levene): p-valor = 0.9293
# ANOVA clásico: p-valor = 0.9087
#
# Variable: caract4
#  - Normalidad en niña: p-valor = 0.2665
#  - Normalidad en niño: p-valor = 0.8630
#  - Homocedasticidad (Levene): p-valor = 0.9751
# ANOVA clásico: p-valor = 0.7331
#
# Variable: caract5
#  - Normalidad en niña: p-valor = 0.2442
#  - Normalidad en niño: p-valor = 0.8852
#  - Homocedasticidad (Levene): p-valor = 0.8468
# ANOVA clásico: p-valor = 0.7213
#
# Variable: caract6
#  - Normalidad en niña: p-valor = 0.6476
#  - Normalidad en niño: p-valor = 0.5404
#  - Homocedasticidad (Levene): p-valor = 0.5546
# ANOVA clásico: p-valor = 0.9449
#
# Variable: caract7
#  - Normalidad en niña: p-valor = 0.5312
#  - Normalidad en niño: p-valor = 0.6027
#  - Homocedasticidad (Levene): p-valor = 0.6173
# ANOVA clásico: p-valor = 0.9270
#
# Variable: caract8
#  - Normalidad en niña: p-valor = 0.4982
#  - Normalidad en niño: p-valor = 0.9613
#  - Homocedasticidad (Levene): p-valor = 0.7131
# ANOVA clásico: p-valor = 0.2944
#
# Variable: caract9
#  - Normalidad en niña: p-valor = 0.4998
#  - Normalidad en niño: p-valor = 0.4851
#  - Homocedasticidad (Levene): p-valor = 0.1788
# ANOVA clásico: p-valor = 0.0634
#
# Variable: caract10
#  - Normalidad en niña: p-valor = 0.6020
#  - Normalidad en niño: p-valor = 0.9552
#  - Homocedasticidad (Levene): p-valor = 0.4331
# ANOVA clásico: p-valor = 0.1491

# %% [markdown]
# Contraste de hipótesis en Abril: Fase El Niño vs Fase La Niña

# %%
df_abr_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_abr_contraste["fecha"] = df_info["fecha"]
df_abr_contraste = df_abr_contraste[df_abr_contraste["fecha"].str[4:] == "04"].reset_index(drop=True)
df_abr_contraste["fases"] = ["neutra", "neutra", "neutra", "neutra", "neutra", "niña", "neutra", "neutra",
                                      "niña", "niña", "neutra", "neutra", "niño", "niño", "neutra",
                                      "niña", "niño", "neutra", "niña", "niña", "neutra", "niño"]
df_abr_contraste = df_abr_contraste[df_abr_contraste["fases"] != "neutra"]
df_abr_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_abr_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niño: p-valor = 0.5961
#  - Normalidad en niña: p-valor = 0.7482
#  - Homocedasticidad (Levene): p-valor = 0.0983
# ANOVA clásico: p-valor = 0.2402
#
# Variable: caract2
#  - Normalidad en niño: p-valor = 0.9101
#  - Normalidad en niña: p-valor = 0.4001
#  - Homocedasticidad (Levene): p-valor = 0.6363
# ANOVA clásico: p-valor = 0.4944
#
# Variable: caract3
#  - Normalidad en niño: p-valor = 0.9179
#  - Normalidad en niña: p-valor = 0.4442
#  - Homocedasticidad (Levene): p-valor = 0.8735
# ANOVA clásico: p-valor = 0.2437
#
# Variable: caract4
#  - Normalidad en niño: p-valor = 0.1151
#  - Normalidad en niña: p-valor = 0.0047
# Mann-Whitney U: p-valor = 0.4762
#
# Variable: caract5
#  - Normalidad en niño: p-valor = 0.6585
#  - Normalidad en niña: p-valor = 0.9470
#  - Homocedasticidad (Levene): p-valor = 0.1829
# ANOVA clásico: p-valor = 0.4087
#
# Variable: caract6
#  - Normalidad en niño: p-valor = 0.2759
#  - Normalidad en niña: p-valor = 0.6977
#  - Homocedasticidad (Levene): p-valor = 0.6464
# ANOVA clásico: p-valor = 0.0850
#
# Variable: caract7
#  - Normalidad en niño: p-valor = 0.9940
#  - Normalidad en niña: p-valor = 0.0175
# Mann-Whitney U: p-valor = 0.9143
#
# Variable: caract8
#  - Normalidad en niño: p-valor = 0.2421
#  - Normalidad en niña: p-valor = 0.0835
#  - Homocedasticidad (Levene): p-valor = 0.3511
# ANOVA clásico: p-valor = 0.8146
#
# Variable: caract9
#  - Normalidad en niño: p-valor = 0.4238
#  - Normalidad en niña: p-valor = 0.5448
#  - Homocedasticidad (Levene): p-valor = 0.4967
# ANOVA clásico: p-valor = 0.2950
#
# Variable: caract10
#  - Normalidad en niño: p-valor = 0.4375
#  - Normalidad en niña: p-valor = 0.5384
#  - Homocedasticidad (Levene): p-valor = 0.2733
# ANOVA clásico: p-valor = 0.1075

# %% [markdown]
# Contraste de hipótesis en Mayo: Fase El Niño vs Fase La Niña

# %%
df_may_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_may_contraste["fecha"] = df_info["fecha"]
df_may_contraste = df_may_contraste[df_may_contraste["fecha"].str[4:] == "05"].reset_index(drop=True)
df_may_contraste["fases"] = ["neutra", "neutra", "neutra", "neutra", "neutra", "niña", "neutra", "neutra",
                                      "niña", "neutra", "neutra", "neutra", "niño", "neutra", "neutra",
                                      "neutra", "niño", "neutra", "niña", "niña", "niño", "neutra"]
df_may_contraste = df_may_contraste[df_may_contraste["fases"] != "neutra"]
df_may_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_may_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niño: p-valor = 0.3777
#  - Normalidad en niña: p-valor = 0.7058
#  - Homocedasticidad (Levene): p-valor = 0.2310
# ANOVA clásico: p-valor = 0.5967
#
# Variable: caract2
#  - Normalidad en niño: p-valor = 0.1090
#  - Normalidad en niña: p-valor = 0.0440
# Mann-Whitney U: p-valor = 0.2286
#
# Variable: caract3
#  - Normalidad en niño: p-valor = 0.9320
#  - Normalidad en niña: p-valor = 0.2041
#  - Homocedasticidad (Levene): p-valor = 0.2960
# ANOVA clásico: p-valor = 0.5548
#
# Variable: caract4
#  - Normalidad en niño: p-valor = 0.7978
#  - Normalidad en niña: p-valor = 0.0100
# Mann-Whitney U: p-valor = 0.4000
#
# Variable: caract5
#  - Normalidad en niño: p-valor = 0.5645
#  - Normalidad en niña: p-valor = 0.3221
#  - Homocedasticidad (Levene): p-valor = 0.2801
# ANOVA clásico: p-valor = 0.0797
#
# Variable: caract6
#  - Normalidad en niño: p-valor = 0.3145
#  - Normalidad en niña: p-valor = 0.2562
#  - Homocedasticidad (Levene): p-valor = 0.5099
# ANOVA clásico: p-valor = 0.3109
#
# Variable: caract7
#  - Normalidad en niño: p-valor = 0.5090
#  - Normalidad en niña: p-valor = 0.3177
#  - Homocedasticidad (Levene): p-valor = 0.6329
# ANOVA clásico: p-valor = 0.1306
#
# Variable: caract8
#  - Normalidad en niño: p-valor = 0.8448
#  - Normalidad en niña: p-valor = 0.7950
#  - Homocedasticidad (Levene): p-valor = 0.3581
# ANOVA clásico: p-valor = 0.4963
#
# Variable: caract9
#  - Normalidad en niño: p-valor = 0.5490
#  - Normalidad en niña: p-valor = 0.8608
#  - Homocedasticidad (Levene): p-valor = 0.4677
# ANOVA clásico: p-valor = 0.4125
#
# Variable: caract10
#  - Normalidad en niño: p-valor = 0.5576
#  - Normalidad en niña: p-valor = 0.7362
#  - Homocedasticidad (Levene): p-valor = 0.7692
# ANOVA clásico: p-valor = 0.6109

# %% [markdown]
# Contraste de hipótesis en Junio: Fase El Niño vs Fase La Niña

# %%
df_jun_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_jun_contraste["fecha"] = df_info["fecha"]
df_jun_contraste = df_jun_contraste[df_jun_contraste["fecha"].str[4:] == "06"].reset_index(drop=True)
df_jun_contraste["fases"] = ["neutra", "neutra", "neutra", "neutra", "niña", "niña", "neutra",
                                      "niña", "neutra", "neutra", "neutra", "neutra", "niño", "neutra",
                                      "neutra", "neutra", "niño", "neutra", "neutra", "niña", "niño","neutra"]
df_jun_contraste = df_jun_contraste[df_jun_contraste["fases"] != "neutra"]
df_jun_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_jun_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niño: p-valor = 0.1390
#  - Normalidad en niña: p-valor = 0.3077
#  - Homocedasticidad (Levene): p-valor = 0.3478
# ANOVA clásico: p-valor = 0.0517
#
# Variable: caract2
#  - Normalidad en niño: p-valor = 0.5062
#  - Normalidad en niña: p-valor = 0.2885
#  - Homocedasticidad (Levene): p-valor = 0.4356
# ANOVA clásico: p-valor = 0.5864
#
# Variable: caract3
#  - Normalidad en niño: p-valor = 0.6415
#  - Normalidad en niña: p-valor = 0.8898
#  - Homocedasticidad (Levene): p-valor = 0.6966
# ANOVA clásico: p-valor = 0.6452
#
# Variable: caract4
#  - Normalidad en niño: p-valor = 0.7718
#  - Normalidad en niña: p-valor = 0.7847
#  - Homocedasticidad (Levene): p-valor = 0.4687
# ANOVA clásico: p-valor = 0.1460
#
# Variable: caract5
#  - Normalidad en niño: p-valor = 0.3369
#  - Normalidad en niña: p-valor = 0.5655
#  - Homocedasticidad (Levene): p-valor = 0.5818
# ANOVA clásico: p-valor = 0.5238
#
# Variable: caract6
#  - Normalidad en niño: p-valor = 0.8003
#  - Normalidad en niña: p-valor = 0.7871
#  - Homocedasticidad (Levene): p-valor = 0.0639
# ANOVA clásico: p-valor = 0.8544
#
# Variable: caract7
#  - Normalidad en niño: p-valor = 0.0409
#  - Normalidad en niña: p-valor = 0.7565
# Mann-Whitney U: p-valor = 1.0000
#
# Variable: caract8
#  - Normalidad en niño: p-valor = 0.9703
#  - Normalidad en niña: p-valor = 0.5989
#  - Homocedasticidad (Levene): p-valor = 0.6877
# ANOVA clásico: p-valor = 0.0908
#
# Variable: caract9
#  - Normalidad en niño: p-valor = 0.8795
#  - Normalidad en niña: p-valor = 0.6195
#  - Homocedasticidad (Levene): p-valor = 0.5278
# ANOVA clásico: p-valor = 0.6921
#
# Variable: caract10
#  - Normalidad en niño: p-valor = 0.1964
#  - Normalidad en niña: p-valor = 0.8545
#  - Homocedasticidad (Levene): p-valor = 0.5912
# ANOVA clásico: p-valor = 0.3184

# %% [markdown]
# Contraste de hipótesis en Julio: Fase El Niño vs Fase La Niña

# %%
df_jul_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_jul_contraste["fecha"] = df_info["fecha"]
df_jul_contraste = df_jul_contraste[df_jul_contraste["fecha"].str[4:] == "07"].reset_index(drop=True)
df_jul_contraste["fases"] = ["neutra", "niño", "neutra", "neutra", "niña", "neutra", "niño",
                                      "niña", "niña", "neutra", "neutra", "neutra", "niño", "neutra",
                                      "neutra", "neutra", "neutra", "neutra", "neutra", "niña", "niño","neutra"]
df_jul_contraste = df_jul_contraste[df_jul_contraste["fases"] != "neutra"]
df_jul_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_jul_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niño: p-valor = 0.7241
#  - Normalidad en niña: p-valor = 0.3013
#  - Homocedasticidad (Levene): p-valor = 0.4967
# ANOVA clásico: p-valor = 0.7605
#
# Variable: caract2
#  - Normalidad en niño: p-valor = 0.7831
#  - Normalidad en niña: p-valor = 0.8909
#  - Homocedasticidad (Levene): p-valor = 0.1195
# ANOVA clásico: p-valor = 0.2931
#
# Variable: caract3
#  - Normalidad en niño: p-valor = 0.2038
#  - Normalidad en niña: p-valor = 0.0776
#  - Homocedasticidad (Levene): p-valor = 0.8884
# ANOVA clásico: p-valor = 0.4291
#
# Variable: caract4
#  - Normalidad en niño: p-valor = 0.8981
#  - Normalidad en niña: p-valor = 0.1965
#  - Homocedasticidad (Levene): p-valor = 0.5139
# ANOVA clásico: p-valor = 0.7837
#
# Variable: caract5
#  - Normalidad en niño: p-valor = 0.8669
#  - Normalidad en niña: p-valor = 0.8318
#  - Homocedasticidad (Levene): p-valor = 0.2129
# ANOVA clásico: p-valor = 0.8570
#
# Variable: caract6
#  - Normalidad en niño: p-valor = 0.6372
#  - Normalidad en niña: p-valor = 0.1740
#  - Homocedasticidad (Levene): p-valor = 0.8087
# ANOVA clásico: p-valor = 0.7130
#
# Variable: caract7
#  - Normalidad en niño: p-valor = 0.3448
#  - Normalidad en niña: p-valor = 0.0242
# Mann-Whitney U: p-valor = 0.3429
#
# Variable: caract8
#  - Normalidad en niño: p-valor = 0.3820
#  - Normalidad en niña: p-valor = 0.6211
#  - Homocedasticidad (Levene): p-valor = 0.9492
# ANOVA clásico: p-valor = 0.6622
#
# Variable: caract9
#  - Normalidad en niño: p-valor = 0.2347
#  - Normalidad en niña: p-valor = 0.9828
#  - Homocedasticidad (Levene): p-valor = 0.7111
# ANOVA clásico: p-valor = 0.5535
#
# Variable: caract10
#  - Normalidad en niño: p-valor = 0.0238
#  - Normalidad en niña: p-valor = 0.2792
# Mann-Whitney U: p-valor = 0.3429

# %% [markdown]
# Contraste de hipótesis en Agosto: Fase El Niño vs Fase La Niña

# %%
df_ago_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_ago_contraste["fecha"] = df_info["fecha"]
df_ago_contraste = df_ago_contraste[df_ago_contraste["fecha"].str[4:] == "08"].reset_index(drop=True)
df_ago_contraste["fases"] = ["niño", "neutra", "niño", "neutra", "neutra", "niña", "neutra", "niño",
                                      "niña", "niña", "neutra", "neutra", "neutra", "niño", "niña",
                                      "neutra", "neutra", "neutra", "niña", "niña", "niña", "niño","neutra"]
df_ago_contraste = df_ago_contraste[df_ago_contraste["fases"] != "neutra"]
df_ago_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_ago_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niño: p-valor = 0.0801
#  - Normalidad en niña: p-valor = 0.5402
#  - Homocedasticidad (Levene): p-valor = 0.7941
# ANOVA clásico: p-valor = 0.8585
#
# Variable: caract2
#  - Normalidad en niño: p-valor = 0.5807
#  - Normalidad en niña: p-valor = 0.8117
#  - Homocedasticidad (Levene): p-valor = 0.5900
# ANOVA clásico: p-valor = 0.3544
#
# Variable: caract3
#  - Normalidad en niño: p-valor = 0.0057
#  - Normalidad en niña: p-valor = 0.4743
# Mann-Whitney U: p-valor = 0.5303
#
# Variable: caract4
#  - Normalidad en niño: p-valor = 0.0767
#  - Normalidad en niña: p-valor = 0.1892
#  - Homocedasticidad (Levene): p-valor = 0.5843
# ANOVA clásico: p-valor = 0.9576
#
# Variable: caract5
#  - Normalidad en niño: p-valor = 0.0957
#  - Normalidad en niña: p-valor = 0.0051
# Mann-Whitney U: p-valor = 0.2020
#
# Variable: caract6
#  - Normalidad en niño: p-valor = 0.2661
#  - Normalidad en niña: p-valor = 0.6138
#  - Homocedasticidad (Levene): p-valor = 0.8786
# ANOVA clásico: p-valor = 0.5930
#
# Variable: caract7
#  - Normalidad en niño: p-valor = 0.2962
#  - Normalidad en niña: p-valor = 0.2109
#  - Homocedasticidad (Levene): p-valor = 0.4178
# ANOVA clásico: p-valor = 0.7162
#
# Variable: caract8
#  - Normalidad en niño: p-valor = 0.4210
#  - Normalidad en niña: p-valor = 0.9726
#  - Homocedasticidad (Levene): p-valor = 0.9057
# ANOVA clásico: p-valor = 0.5116
#
# Variable: caract9
#  - Normalidad en niño: p-valor = 0.8709
#  - Normalidad en niña: p-valor = 0.2314
#  - Homocedasticidad (Levene): p-valor = 0.1541
# ANOVA clásico: p-valor = 0.2291
#
# Variable: caract10
#  - Normalidad en niño: p-valor = 0.4036
#  - Normalidad en niña: p-valor = 0.0740
#  - Homocedasticidad (Levene): p-valor = 0.8569
# ANOVA clásico: p-valor = 0.9585

# %% [markdown]
# Contraste de hipótesis en Septiembre: Fase El Niño vs Fase La Niña

# %%
df_sep_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_sep_contraste["fecha"] = df_info["fecha"]
df_sep_contraste = df_sep_contraste[df_sep_contraste["fecha"].str[4:] == "09"].reset_index(drop=True)
df_sep_contraste["fases"] = ["niño", "neutra", "niño", "neutra", "niño", "niña", "neutra", "niño",
                                      "niña", "niña", "neutra", "neutra", "neutra", "niño", "niña",
                                      "neutra", "niño", "neutra", "niña", "niña", "niña", "niño","neutra"]
df_sep_contraste = df_sep_contraste[df_sep_contraste["fases"] != "neutra"]
df_sep_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_sep_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niño: p-valor = 0.9555
#  - Normalidad en niña: p-valor = 0.9995
#  - Homocedasticidad (Levene): p-valor = 0.3739
# ANOVA clásico: p-valor = 0.6822
#
# Variable: caract2
#  - Normalidad en niño: p-valor = 0.7618
#  - Normalidad en niña: p-valor = 0.0240
# Mann-Whitney U: p-valor = 0.8048
#
# Variable: caract3
#  - Normalidad en niño: p-valor = 0.9434
#  - Normalidad en niña: p-valor = 0.6063
#  - Homocedasticidad (Levene): p-valor = 0.3850
# ANOVA clásico: p-valor = 0.5600
#
# Variable: caract4
#  - Normalidad en niño: p-valor = 0.8180
#  - Normalidad en niña: p-valor = 0.9361
#  - Homocedasticidad (Levene): p-valor = 0.4838
# ANOVA clásico: p-valor = 0.9551
#
# Variable: caract5
#  - Normalidad en niño: p-valor = 0.2383
#  - Normalidad en niña: p-valor = 0.0148
# Mann-Whitney U: p-valor = 0.0973
#
# Variable: caract6
#  - Normalidad en niño: p-valor = 0.1606
#  - Normalidad en niña: p-valor = 0.2454
#  - Homocedasticidad (Levene): p-valor = 0.6394
# ANOVA clásico: p-valor = 0.6723
#
# Variable: caract7
#  - Normalidad en niño: p-valor = 0.1899
#  - Normalidad en niña: p-valor = 0.0980
#  - Homocedasticidad (Levene): p-valor = 0.6955
# ANOVA clásico: p-valor = 0.1003
#
# Variable: caract8
#  - Normalidad en niño: p-valor = 0.7407
#  - Normalidad en niña: p-valor = 0.2939
#  - Homocedasticidad (Levene): p-valor = 0.5348
# ANOVA clásico: p-valor = 0.8346
#
# Variable: caract9
#  - Normalidad en niño: p-valor = 0.8288
#  - Normalidad en niña: p-valor = 0.0501
#  - Homocedasticidad (Levene): p-valor = 0.2142
# ANOVA clásico: p-valor = 0.5194
#
# Variable: caract10
#  - Normalidad en niño: p-valor = 0.0755
#  - Normalidad en niña: p-valor = 0.6332
#  - Homocedasticidad (Levene): p-valor = 0.8955
# ANOVA clásico: p-valor = 0.3824

# %% [markdown]
# Contraste de hipótesis en Octubre: Fase El Niño vs Fase La Niña

# %%
df_oct_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_oct_contraste["fecha"] = df_info["fecha"]
df_oct_contraste = df_oct_contraste[df_oct_contraste["fecha"].str[4:] == "10"].reset_index(drop=True)
df_oct_contraste["fases"] = ["niño", "neutra", "niño", "neutra", "niño", "niña", "neutra", "niño",
                                      "niña", "niña", "neutra", "neutra", "niño", "niño", "niña",
                                      "niña", "niño", "neutra", "niña", "niña", "niña", "niño","neutra"]
df_oct_contraste = df_oct_contraste[df_oct_contraste["fases"] != "neutra"]
df_oct_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_oct_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niño: p-valor = 0.5200
#  - Normalidad en niña: p-valor = 0.0055
# Mann-Whitney U: p-valor = 0.2786
#
# Variable: caract2
#  - Normalidad en niño: p-valor = 0.5179
#  - Normalidad en niña: p-valor = 0.8894
#  - Homocedasticidad (Levene): p-valor = 0.2895
# ANOVA clásico: p-valor = 0.0647
#
# Variable: caract3
#  - Normalidad en niño: p-valor = 0.1171
#  - Normalidad en niña: p-valor = 0.2728
#  - Homocedasticidad (Levene): p-valor = 0.0011
# Welch's ANOVA: p-valor = 0.9865
#
# Variable: caract4
#  - Normalidad en niño: p-valor = 0.2161
#  - Normalidad en niña: p-valor = 0.2824
#  - Homocedasticidad (Levene): p-valor = 0.3534
# ANOVA clásico: p-valor = 0.0234
#
# Variable: caract5
#  - Normalidad en niño: p-valor = 0.9204
#  - Normalidad en niña: p-valor = 0.4383
#  - Homocedasticidad (Levene): p-valor = 0.9440
# ANOVA clásico: p-valor = 0.6111
#
# Variable: caract6
#  - Normalidad en niño: p-valor = 0.0823
#  - Normalidad en niña: p-valor = 0.5672
#  - Homocedasticidad (Levene): p-valor = 0.2145
# ANOVA clásico: p-valor = 0.0162
#
# Variable: caract7
#  - Normalidad en niño: p-valor = 0.2987
#  - Normalidad en niña: p-valor = 0.2209
#  - Homocedasticidad (Levene): p-valor = 0.4946
# ANOVA clásico: p-valor = 0.1310
#
# Variable: caract8
#  - Normalidad en niño: p-valor = 0.5109
#  - Normalidad en niña: p-valor = 0.8095
#  - Homocedasticidad (Levene): p-valor = 0.5455
# ANOVA clásico: p-valor = 0.0029
#
# Variable: caract9
#  - Normalidad en niño: p-valor = 0.8092
#  - Normalidad en niña: p-valor = 0.4870
#  - Homocedasticidad (Levene): p-valor = 0.4658
# ANOVA clásico: p-valor = 0.1746
#
# Variable: caract10
#  - Normalidad en niño: p-valor = 0.6276
#  - Normalidad en niña: p-valor = 0.9832
#  - Homocedasticidad (Levene): p-valor = 0.4180
# ANOVA clásico: p-valor = 0.7874

# %% [markdown]
# Contraste de hipótesis en Noviembre: Fase El Niño vs Fase La Niña

# %%
df_nov_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_nov_contraste["fecha"] = df_info["fecha"]
df_nov_contraste = df_nov_contraste[df_nov_contraste["fecha"].str[4:] == "11"].reset_index(drop=True)
df_nov_contraste["fases"] = ["niño", "neutra", "niño", "niña", "niño", "niña",
                                      "niña", "niño", "niña", "niña", "neutra", "neutra",
                                      "niño", "niño", "niña", "niña", "niño", "neutra",
                                      "niña", "niña", "niña", "niño", "neutra"]
df_nov_contraste = df_nov_contraste[df_nov_contraste["fases"] != "neutra"]
df_nov_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_nov_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niño: p-valor = 0.3890
#  - Normalidad en niña: p-valor = 0.5980
#  - Homocedasticidad (Levene): p-valor = 0.4691
# ANOVA clásico: p-valor = 0.0129
#
# Variable: caract2
#  - Normalidad en niño: p-valor = 0.6954
#  - Normalidad en niña: p-valor = 0.3250
#  - Homocedasticidad (Levene): p-valor = 0.0950
# ANOVA clásico: p-valor = 0.0028
#
# Variable: caract3
#  - Normalidad en niño: p-valor = 0.4223
#  - Normalidad en niña: p-valor = 0.0321
# Mann-Whitney U: p-valor = 0.8286
#
# Variable: caract4
#  - Normalidad en niño: p-valor = 0.6692
#  - Normalidad en niña: p-valor = 0.0826
#  - Homocedasticidad (Levene): p-valor = 0.5917
# ANOVA clásico: p-valor = 0.0028
#
# Variable: caract5
#  - Normalidad en niño: p-valor = 0.5057
#  - Normalidad en niña: p-valor = 0.1797
#  - Homocedasticidad (Levene): p-valor = 0.2144
# ANOVA clásico: p-valor = 0.4040
#
# Variable: caract6
#  - Normalidad en niño: p-valor = 0.3880
#  - Normalidad en niña: p-valor = 0.7054
#  - Homocedasticidad (Levene): p-valor = 0.4321
# ANOVA clásico: p-valor = 0.8862
#
# Variable: caract7
#  - Normalidad en niño: p-valor = 0.1654
#  - Normalidad en niña: p-valor = 0.0224
# Mann-Whitney U: p-valor = 0.3154
#
# Variable: caract8
#  - Normalidad en niño: p-valor = 0.0501
#  - Normalidad en niña: p-valor = 0.3148
#  - Homocedasticidad (Levene): p-valor = 0.0021
# Welch: p-valor = 0.2488
#
# Variable: caract9
#  - Normalidad en niño: p-valor = 0.0677
#  - Normalidad en niña: p-valor = 0.8074
#  - Homocedasticidad (Levene): p-valor = 0.3342
# ANOVA clásico: p-valor = 0.8132
#
# Variable: caract10
#  - Normalidad en niño: p-valor = 0.8384
#  - Normalidad en niña: p-valor = 0.0652
#  - Homocedasticidad (Levene): p-valor = 0.2641
# ANOVA clásico: p-valor = 0.6136

# %% [markdown]
# Contraste de hipótesis en Diciembre: Fase El Niño vs Fase La Niña

# %%
df_dic_contraste = pd.DataFrame(espacio_latente,
                                columns=["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"])
df_dic_contraste["fecha"] = df_info["fecha"]
df_dic_contraste = df_dic_contraste[df_dic_contraste["fecha"].str[4:] == "12"].reset_index(drop=True)
df_dic_contraste["fases"] = ["niño", "neutra", "niño", "niña", "niño", "niña",
                                      "niña", "niño", "niña", "niña", "neutra", "neutra",
                                      "niño", "niño", "niña", "niña", "niño", "neutra",
                                      "niña", "niña", "niña", "niño", "neutra"]
df_dic_contraste = df_dic_contraste[df_dic_contraste["fases"] != "neutra"]
df_dic_contraste

for col in ["caract1", "caract2", "caract3","caract4", "caract5", "caract6",
                                         "caract7", "caract8", "caract9", "caract10"]:
  analizar_contraste(df_dic_contraste, col)
# Out:
# Variable: caract1
#  - Normalidad en niño: p-valor = 0.9792
#  - Normalidad en niña: p-valor = 0.8052
#  - Homocedasticidad (Levene): p-valor = 0.7136
# ANOVA clásico: p-valor = 0.1790
#
# Variable: caract2
#  - Normalidad en niño: p-valor = 0.0127
#  - Normalidad en niña: p-valor = 0.3816
# Mann-Whitney U: p-valor = 0.0545
#
# Variable: caract3
#  - Normalidad en niño: p-valor = 0.0836
#  - Normalidad en niña: p-valor = 0.1193
#  - Homocedasticidad (Levene): p-valor = 0.2432
# ANOVA clásico: p-valor = 0.1377
#
# Variable: caract4
#  - Normalidad en niño: p-valor = 0.6678
#  - Normalidad en niña: p-valor = 0.5881
#  - Homocedasticidad (Levene): p-valor = 0.7962
# ANOVA clásico: p-valor = 0.0083
#
# Variable: caract5
#  - Normalidad en niño: p-valor = 0.1185
#  - Normalidad en niña: p-valor = 0.4910
#  - Homocedasticidad (Levene): p-valor = 0.0544
# ANOVA clásico: p-valor = 0.0983
#
# Variable: caract6
#  - Normalidad en niño: p-valor = 0.2909
#  - Normalidad en niña: p-valor = 0.1549
#  - Homocedasticidad (Levene): p-valor = 0.6210
# ANOVA clásico: p-valor = 0.0344
#
# Variable: caract7
#  - Normalidad en niño: p-valor = 0.4703
#  - Normalidad en niña: p-valor = 0.6012
#  - Homocedasticidad (Levene): p-valor = 0.6414
# ANOVA clásico: p-valor = 0.1317
#
# Variable: caract8
#  - Normalidad en niño: p-valor = 0.8502
#  - Normalidad en niña: p-valor = 0.3039
#  - Homocedasticidad (Levene): p-valor = 0.2948
# ANOVA clásico: p-valor = 0.0048
#
# Variable: caract9
#  - Normalidad en niño: p-valor = 0.0019
#  - Normalidad en niña: p-valor = 0.2054
# Mann-Whitney U: p-valor = 0.0434
#
# Variable: caract10
#  - Normalidad en niño: p-valor = 0.2249
#  - Normalidad en niña: p-valor = 0.2972
#  - Homocedasticidad (Levene): p-valor = 0.4458
# ANOVA clásico: p-valor = 0.2657
